# %%
# !pip install openai
# !pip install pandas
# Out:
# Requirement already satisfied: openai in /Users/mac/miniconda3/lib/python3.12/site-packages (1.43.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/mac/miniconda3/lib/python3.12/site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/mac/miniconda3/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/mac/miniconda3/lib/python3.12/site-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/mac/miniconda3/lib/python3.12/site-packages (from openai) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/mac/miniconda3/lib/python3.12/site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /Users/mac/miniconda3/lib/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/mac/miniconda3/lib/python3.12/site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/mac/miniconda3/lib/python3.12/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /Users/mac/miniconda3/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in /Users/mac/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /Users/mac/miniconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/mac/miniconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/mac/miniconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/mac/miniconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: pandas in /Users/mac/miniconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /Users/mac/miniconda3/lib/python3.12/site-packages (from pandas) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mac/miniconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mac/miniconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mac/miniconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/mac/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import os
from dotenv import load_dotenv, find_dotenv
from openai import OpenAI

_ = load_dotenv(find_dotenv())
client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])
# Function to ask GPT for the part of speech, meaning, and example sentence of a word

def ask_gpt(word):
    # This function sends a request to GPT to get the part of speech, meaning, and example sentence for the word
    response = client.chat.completions.create(
        model="gpt-4",  # Adjust the model to the appropriate version like 'gpt-4' or 'gpt-3.5-turbo'
        messages=[
            {
                'role': 'system',
                'content': (
                    'You are an English language expert who gives direct, to-the-point answers. '
                    'When the user asks you the part of speech, meaning, and sentence for a word, you directly provide it. '
                    'For example:\n'
                    'user: Give the part of speech, meaning, and sentence for the word affront?\n'
                    'assistant: Noun, An action or remark that causes outrage or offense. '
                    'Example sentence: His rude behavior was an affront to everyone in the room.'
                )
            },
            {
                'role': 'user',
                'content': f'Give the part of speech, meaning, and sentence for the word {word}.'
            }
        ]
    )
    
    # Extracting the response from GPT
    answer = response.choices[0].message.content.strip()
    return answer

# Read the CSV file containing the list of words into a Pandas DataFrame
df = pd.read_csv('sample_word_list.csv')

# Add new columns to the DataFrame for part of speech, meaning, and sentence
df['Part of Speech'] = ''
df['Meaning'] = ''
df['Example Sentence'] = ''

# Iterate through each row in the DataFrame
for index, row in df.iterrows():
    word = row['Word']  # Get the word from the row

    # Get the part of speech, meaning, and sentence by calling the ask_gpt function
    result = ask_gpt(word)
    
    # Split the result (assuming it returns in the form "Part of Speech, Meaning. Example Sentence: ...")
    try:
        # Extract part of speech, meaning, and example sentence
        part_of_speech, rest = result.split(",", 1)  # Get part of speech and the rest
        meaning, sentence = rest.split("Example sentence:", 1)  # Split meaning and sentence
        
        # Update the DataFrame with the part of speech, meaning, and example sentence
        df.at[index, 'Part of Speech'] = part_of_speech.strip()
        df.at[index, 'Meaning'] = meaning.strip()
        df.at[index, 'Example Sentence'] = sentence.strip()
    
    except ValueError:
        # If GPT response is in an unexpected format, leave the fields blank or handle appropriately
        print(f"Error processing word: {word}")

    # Print for monitoring progress
    print(f"Word: {word}\nPart of Speech: {part_of_speech.strip()}\nMeaning: {meaning.strip()}\nSentence: {sentence.strip()}\n")

# Save the updated DataFrame to an Excel file
df.to_excel('pi.xlsx', index=False)

print("Completed updating the meanings.")
# Out:
# Word: Affront
# Part of Speech: Noun
# Meaning: An action or remark that causes outrage or offense.
# Sentence: His rude behavior was an affront to everyone in the room.
#
# Word: Benevolent
# Part of Speech: Adjective
# Meaning: Well-meaning and kindly.
# Sentence: We should all aspire to be as benevolent as Mother Teresa.
#
# Word: Cacophony
# Part of Speech: Noun
# Meaning: A harsh, discordant mixture of sounds.
# Sentence: The cacophony of the city traffic was giving me a headache.
#
# Word: Dauntless
# Part of Speech: Adjective
# Meaning: Showing fearlessness and determination.
# Sentence: His dauntless courage allowed him to stand up and face the adversity without flinching.
#
# Word: Ebullient
# Part of Speech: Adjective
# Meaning: Being cheerful and full of energy.
# Sentence: He was ebullient and passionate about his work.
#
# Completed updating the meanings.
